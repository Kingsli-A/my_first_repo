# %%
#pandas 
#pandas is a python library
#pandas is used to analyze tha data sets
#functions
#1.analyzing
#2.clenaing
#3.exploring
#4.manipluting data

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#dataframe
import pandas as pd
mydataset={'cars':["BMW","VOLVO","FORD"],
           'Passing':[3,7,2]}
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  Passing
# 0    BMW        3
# 1  VOLVO        7
# 2   FORD        2

# %%
import pandas
mydataset={'cars':["BMW","VOLVO","FORD"],
           'Passing':[3,7,2],
          'colours':["yellow","blue","red"]}
myvar=pandas.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  Passing colours
# 0    BMW        3  yellow
# 1  VOLVO        7    blue
# 2   FORD        2     red

# %%
#series
import pandas as pd
a=[1,2,3]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
#create lables 
a=[1,7,2]
myvar=pd.Series(a,index=['x','y','z'])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
a=["abi","jeenath","gowt"]
myvar=pd.Series(a,index=['x','y','z'])
print(myvar['y'])
# Out:
# jeenath

# %%
#key/value objects as series:
calories={"day1":420,"day2":380,"day3":390}
myvar=pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories={"day1":420,"day2":380,"day3":390}
myvar=pd.Series(calories)
print(myvar["day2"])
print(myvar[0:2])
# Out:
# 380
# day1    420
# day2    380
# dtype: int64

# %%
print(pd.__version__)
# Out:
# 2.1.4

# %%
#locate row:
import pandas as pd
mydataset={'cars':["BMW","VOLVO","FORD"],
           'Passing':[3,7,2],
          'colour':["white","yellow","blue"]}
myvar=pd.DataFrame(mydataset)
#print(myvar.loc[[0,1]])
#print(myvar.loc[0])

# %%
#locate named index:
df=pd.read_csv(r'C:\Users\LENOVO\Downloads\customers-100.csv')
#(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #locate named index:
# ----> 2 df=pd.read_csv(r'C:\Users\LENOVO\Downloads\customers-100.csv')
#
# NameError: name 'pd' is not defined

# %%
#max_rows
import pandas as pd
df=pd.read_csv(r'C:\Users\LENOVO\Downloads\customers-100.csv')

#print(df.to_string)
#pd.options.display.max_rows=1000
#print(pd.options.display.max_rows)
#print(pd.options.display.min_rows)
#print(pd.options.display.max_rows==60)
print(df.sample(10))
# Out:
#     Index      Customer Id First Name Last Name                     Company  \
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young     Lee, Lucero and Johnson
# 38     39  dca4f1D0A0fc5c9      Bruce   Esparza               Huerta-Mclean
# 12     13  e35426EbDEceaFF     Tracey      Mata              Graham-Francis
# 67     68  a014Ec1b9FccC1E        Tom  Alvarado         Donaldson-Dougherty
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra               Schmitt-Jones
# 73     74  A3F76Be153Df4a3      Anita    Benson                 Parrish Ltd
# 77     78  FfaeFFbbbf280db    Cassidy   Mcmahon  Mcguire, Huynh and Hopkins
# 81     82  Ebdb6F6F7c90b69   Kathleen     Mckay    Coffey, Lamb and Johnson
# 75     76  d40e89dCade7b2F      Debra    Riddle  Chang, Aguirre and Leblanc
# 87     88  E4Bbcd8AD81fC5f     Alison    Vargas     Vaughn, Watts and Leach
#
#                   City                           Country  \
# 93        Frankchester                   Solomon Islands
# ...

# %%
import pandas as pd
df=pd.read_json(r"C:\Users\LENOVO\Desktop\abi.json")
print(df.info())
print("------------------------------")
print(df.to_string())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 2 to 1
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  167 non-null    float64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 6.6 KB
# None
# ------------------------------
#      Duration  Pulse  Maxpulse  Calories
# 2        60.0    103       135     340.0
# 3        45.0    109       175     282.4
# 4        45.0    117       148     406.0
# 5        60.0    102       127     300.5
# 6        60.0    110       136     374.0
# 7        45.0    104       134     253.3
# 8        30.0    109       133     195.1
# 9        60.0     98       124     269.0
# 10       60.0    103       147     329.3
# 11       60.0    100       120     250.7
# 12       60.0    106       128     345.3
# 13       60.0    104       132     379.3
# ...

# %%
import pandas as pd
l=[10,20,30,40,50]
pd.Series(l,index=[1,2,3,4,5])
#print(w)
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# 5    50
# dtype: int64

# %%
import pandas as pd
l=[10,20,30,40,100]
pd.Series(l)
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4    100
# dtype: int64

# %%
import pandas as pd
d={'name':["abi","raj","raju"],'percentage':[98,90,95]}
pd.Series(d)
# Out:
# name          [abi, raj, raju]
# percentage        [98, 90, 95]
# dtype: object

# %%
import pandas as pd
d={'name':["abi","raj","raju"],'percentage':[98,90,95]}
pd.DataFrame(d,index=[1,2,3])
# Out:
#    name  percentage
# 1   abi          98
# 2   raj          90
# 3  raju          95

# %%
import pandas as pd
d={'name':("abi","raj","raju"),'percentage':(98,90,95)}
pd.DataFrame(d,index=[1,2,3])
# Out:
#    name  percentage
# 1   abi          98
# 2   raj          90
# 3  raju          95

# %%
import pandas as pd

calories = {"day1": [420], "day2": [380], "day3": [390]}
pd.DataFrame(calories)
# Out:
#    day1  day2  day3
# 0   420   380   390

# %%
import pandas as pd
calories = {"years": [420, 380, 390],"decades":[4,3,3.5]}
pd.DataFrame(calories)
# Out:
#    years  decades
# 0    420      4.0
# 1    380      3.0
# 2    390      3.5

# %%
import pandas as pd
user={"Name":["Abi","Jeenath","Gowtham","Praveen","Kavya","Vignesh"],
      "Branch":["IT","IT","IT","ECE","EEE","MECH"],
      "Percentage":['90%','90%','90%','95%','97%','98%']}
pd.DataFrame(user,index=[1,2,3,4,5,6])
# Out:
#       Name Branch Percentage
# 1      Abi     IT        90%
# 2  Jeenath     IT        90%
# 3  Gowtham     IT        90%
# 4  Praveen    ECE        95%
# 5    Kavya    EEE        97%
# 6  Vignesh   MECH        98%

# %%
d=[("abi",90,"IT"),("Jeenath",90,"IT")]
pd.DataFrame(d)
# Out:
#          0   1   2
# 0      abi  90  IT
# 1  Jeenath  90  IT

# %%
user={"Name":("Abi","Jeenath","Gowtham","Praveen","Kavya","Vignesh"),
      "Branch":("IT","IT","IT","ECE","EEE","MECH"),
      "Percentage":('90%','90%','90%','95%','97%','98%')}
pd.DataFrame(user,index=[1,2,3,4,5,6])
# Out:
#       Name Branch Percentage
# 1      Abi     IT        90%
# 2  Jeenath     IT        90%
# 3  Gowtham     IT        90%
# 4  Praveen    ECE        95%
# 5    Kavya    EEE        97%
# 6  Vignesh   MECH        98%

# %%
s = pd.Series([1, 2, 3])
s.shape
# Out:
# (3,)

# %%
user={"Name":("Abi","Jeenath","Gowtham","Praveen","Kavya","Vignesh"),
      "Branch":("IT","IT","IT","ECE","EEE","MECH"),
      "Percentage":('90%','90%','90%','95%','97%','98%')}
df=pd.DataFrame(user)
#print(df.head())
print(df.head(3))
# Out:
#       Name Branch Percentage
# 0      Abi     IT        90%
# 1  Jeenath     IT        90%
# 2  Gowtham     IT        90%

# %%
df=pd.read_csv(r'C:\Users\LENOVO\Downloads\customers-100.csv')
e=pd.DataFrame(df)
#print(e.head())
#print(e.info())
print(e.tail(2))
# Out:
#     Index      Customer Id First Name Last Name             Company  \
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer  Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes  Le, Nash and Cross
#
#                City   Country        Phone 1                 Phone 2  \
# 98  Lake Elijahview     Aruba  (530)311-9786  001-869-452-0943x12424
# 99        Judymouth  Honduras  (753)813-6941            783.639.1472
#
#                              Email Subscription Date  \
# 98  mccarthystephen@horn-green.biz        2021-08-11
# 99          colleen91@faulkner.biz        2020-03-11
#
#                               Website
# 98               http://watkins.info/
# 99  http://www.hatfield-saunders.net/

# %%
df=pd.read_csv(r'C:\Users\LENOVO\Downloads\customers-100.csv')
new_df=df.dropna()
#print(new_df.to_string())
print(new_df)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\info.csv")
new=df.dropna()
print(new)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\info.csv")
print(df.shape)
# Out:
# (32, 5)

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\info.csv")
df.dropna(inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\info.csv")
df.fillna(130,inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\info.csv")
df["Date"].fillna(2020/12/2,inplace=True)
df["Calories"].fillna(300.4,inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#Replace Using Mean, Median, or Mode

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\info.csv")
#print(df)
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)
df.info()
print(df.to_string())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      32 non-null     datetime64[ns]
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.4 KB
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-01-12    110       130     409.1
# 1         60 2020-02-12    117       145     479.0
# 2         60 2020-03-12    103       135     340.0
# 3         45 2020-04-12    109       175     282.4
# 4         45 2020-05-12    117       148     406.0
# 5         60 2020-04-12    102       127     300.0
# 6         60 2020-04-12    110       136     374.0
# 7        450 2020-04-12    104       134     253.3
# 8         30 2020-04-12    109       133     195.1
# ...

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\dateTime.csv")
data['Date']=pd.to_datetime(data['Date'])
print(data.to_string())
print(data.info())
# Out:
#      Duration  Pulse  Maxpulse  Calories       Date
# 0          60    110       130     409.1 2020-12-01
# 1          60    117       145     479.0 2020-12-02
# 2          60    103       135     340.0 2020-12-03
# 3          45    109       175     282.4 2020-12-04
# 4          45    117       148     406.0 2020-12-05
# 5          60    102       127     300.0 2020-12-06
# 6          60    110       136     374.0 2020-12-07
# 7          45    104       134     253.3 2020-12-08
# 8          30    109       133     195.1 2020-12-09
# 9          60     98       124     269.0 2020-12-10
# 10         60    103       147     329.3 2020-12-11
# 11         60    100       120     250.7 2020-12-12
# 12         60    106       128     345.3 2020-12-12
# 13         60    104       132     379.3 2020-12-13
# 14         60     98       123     275.0 2020-12-14
# 15         60     98       120     215.2 2020-12-15
# 16         60    100       120     300.0 2020-12-16
# ...

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\dateTime.csv")
data['Date']=pd.to_datetime(data['Date'])
print(data.to_string())
data['Calories'].unique()
data['Calories'].value_counts()
data['Calories'].value_counts(normalize=True)
# Out:
#      Duration  Pulse  Maxpulse  Calories       Date
# 0          60    110       130     409.1 2020-12-01
# 1          60    117       145     479.0 2020-12-02
# 2          60    103       135     340.0 2020-12-03
# 3          45    109       175     282.4 2020-12-04
# 4          45    117       148     406.0 2020-12-05
# 5          60    102       127     300.0 2020-12-06
# 6          60    110       136     374.0 2020-12-07
# 7          45    104       134     253.3 2020-12-08
# 8          30    109       133     195.1 2020-12-09
# 9          60     98       124     269.0 2020-12-10
# 10         60    103       147     329.3 2020-12-11
# 11         60    100       120     250.7 2020-12-12
# 12         60    106       128     345.3 2020-12-12
# 13         60    104       132     379.3 2020-12-13
# 14         60     98       123     275.0 2020-12-14
# 15         60     98       120     215.2 2020-12-15
# 16         60    100       120     300.0 2020-12-16
# ...

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\dateTime.csv")
data['Date']=pd.to_datetime(data['Date'])
#print(data.to_string())
#data['Calories'].unique()
#data['Calories'].value_counts()
data['Calories'].value_counts(normalize=True)
# Out:
# Calories
# 300.0    0.060976
# 500.0    0.018293
# 270.4    0.012195
# 225.3    0.012195
# 500.4    0.012195
#            ...
# 413.0    0.006098
# 450.7    0.006098
# 238.0    0.006098
# 486.0    0.006098
# 330.4    0.006098
# Name: proportion, Length: 142, dtype: float64

# %%
data['Calories'].unique()
# Out:
# array([ 409.1,  479. ,  340. ,  282.4,  406. ,  300. ,  374. ,  253.3,
#         195.1,  269. ,  329.3,  250.7,  345.3,  379.3,  275. ,  215.2,
#           nan,  323. ,  243. ,  364.2,  282. ,  246. ,  334.5,  250. ,
#         241. ,  280. ,  380.3,  180.1,  299. ,  223. ,  361. ,  415. ,
#         266. ,  286. ,  329.4,  400. ,  397. ,  273. ,  387.6,  298. ,
#         397.6,  380.2,  643.1,  263. ,  486. ,  238. ,  450.7,  413. ,
#         305. ,  226.4,  321. , 1376. , 1034.4,  853. ,  341. ,  131.4,
#         800.4,  873.4,  816. ,  110.4, 1500.2, 1115. ,  700. ,  953.2,
#         304. ,  563.2,  251. ,  500.4, 1729. ,  319.2,  344. ,  151.1,
#         500. ,  225.3,  234. , 1000.1,  242. ,   50.3,  600.1,  105.3,
#          50.5,  127.4,  229.4,  128.2,  244.2,  188.2,  604.1,   77.7,
#          92.7,  124. ,  800.3,   86.2,  500.3, 1860.4,  325.2,  124.2,
#         367.6,  351.7,  443. ,  277.4,  332.7,  193.9,  100.7,  336.7,
# ...

# %%
data['Calories'].value_counts()
# Out:
# Calories
# 300.0    10
# 500.0     3
# 270.4     2
# 225.3     2
# 500.4     2
#          ..
# 413.0     1
# 450.7     1
# 238.0     1
# 486.0     1
# 330.4     1
# Name: count, Length: 142, dtype: int64

# %%
data['Calories'].mode()
# Out:
# 0    300.0
# Name: Calories, dtype: float64

# %%
data['Calories'].mean()
# Out:
# 375.79024390243904

# %%
data['Calories'].median()
# Out:
# 318.6

# %%
data.groupby(['Duration'])['Pulse'].median()
# Out:
# Duration
# 15     102.0
# 20     136.0
# 25     152.0
# 30     103.0
# 45     106.0
# 60     106.0
# 75     122.5
# 80     123.0
# 90      91.5
# 120    100.0
# 150    101.0
# 160    109.5
# 180     90.0
# 210    122.5
# 270    100.0
# 300    108.0
# Name: Pulse, dtype: float64

# %%
data.groupby(['Duration'])['Pulse'].mean()
#print(data.to_string())
# Out:
# Duration
# 15     102.000000
# 20     125.000000
# 25     152.000000
# 30     109.812500
# 45     107.485714
# 60     106.126582
# 75     122.500000
# 80     123.000000
# 90      93.750000
# 120    100.000000
# 150    101.500000
# 160    109.500000
# 180     93.666667
# 210    122.500000
# 270    100.000000
# 300    108.000000
# Name: Pulse, dtype: float64

# %%
#fnction--
def increse(s):
    return s+s*0.100
data['Pulse'].apply(increse)
data['New_Pulse'] = data['Pulse'].apply(increse)
def increse(d):
    return d+d*200
data['Duration'].apply(increse)
data['newduration'] = data ['Duration'].apply(increse)

data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories       Date  New_Price  New_Pulse  \
# 0        60    110       130     409.1 2020-12-01      121.0      121.0
# 1        60    117       145     479.0 2020-12-02      128.7      128.7
# 2        60    103       135     340.0 2020-12-03      113.3      113.3
# 3        45    109       175     282.4 2020-12-04      119.9      119.9
# 4        45    117       148     406.0 2020-12-05      128.7      128.7
#
#    newduration
# 0        12060
# 1        12060
# 2        12060
# 3         9045
# 4         9045

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\weight-height.csv")
df.head()
df.Weight.describe()
df.Height.describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\weight-height.csv")
#sns.histplot(df.Height,kde=True)
#kde=kernl density estimation
#df[(df.Height<54.82)|(df.Height>77.91)]
df_no_outlier = df[(df.Height<77.91) & (df.Height>54.82)]
df_no_outlier
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [9993 rows x 3 columns]

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\weight-height.csv")
df['zscore'] = ( df.Height - df.Height.mean() ) / df.Height.std()
df.head(5)
# Out:
#   Gender     Height      Weight    zscore
# 0   Male  73.847017  241.893563  1.943964
# 1   Male  68.781904  162.310473  0.627505
# 2   Male  74.110105  212.740856  2.012343
# 3   Male  71.730978  220.042470  1.393991
# 4   Male  69.881796  206.349801  0.913375
