# %%
#-----------------series--------------------------------
import pandas as pd
#how to create an empty series...
#how to create a series in arrays
#series using lists
#series using dictinary
empty=pd.Series()
empty
# Out:
# Series([], dtype: object)

# %%
#series create list
list=pd.Series([10,20,30,40,],index=[1,2,3,4])
list



#add
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# dtype: int64

# %%
import numpy as np
import pandas as pd
a=np.array([60,70,80,90,100])
a
bs=pd.Series(a)
bs
# Out:
# 0     60
# 1     70
# 2     80
# 3     90
# 4    100
# dtype: int32

# %%
import pandas as pd
dict=pd.Series({"name":"abi","age":"22"})
dict
# Out:
# name    abi
# age      22
# dtype: object

# %%
dt=[('a',100),('b',200)]
pd.Series(dt)
#print(len(dt))
# Out:
# 0    (a, 100)
# 1    (b, 200)
# dtype: object

# %%
#----------------------------DataFrame-------------------------------------
#1->Load the data from xlsx file
#2 ->load the data from csv file(comma separated value)
#3 ->create df from dictionary
#4 ->create of df using list of tuples
import pandas as pa
pd.read_csv

# %%
import pandas as pd
d={"name":['abi',"vijay","surya"],"marks":[92,80,85]}
pd.DataFrame(d)
#print(d)
# Out:
#     name  marks
# 0    abi     92
# 1  vijay     80
# 2  surya     85

# %%
t=[('abc','cse','90'),("def","sdd","85")]
pd.DataFrame(t,index=["i","j"])
# Out:
#      0    1   2
# i  abc  cse  90
# j  def  sdd  85

# %%
import pandas as pd
xl=pd.read_excel(r"C:\Users\LENOVO\Desktop\pandas\FSI-2023-DOWNLOAD.xlsx")
xl.sample(10)
# Out:
#           Country  Year   Rank  Total  S1: Demographic Pressures  \
# 20   Burkina Faso  2023   21st   94.0                        8.3
# 36     Mauritania  2023   37th   87.0                        8.6
# 160         Japan  2023  161st   30.5                        5.9
# 56       Honduras  2023   57th   79.6                        6.9
# 0         Somalia  2023    1st  111.9                       10.0
# 149    Costa Rica  2023  150th   40.4                        2.9
# 107       Jamaica  2023  108th   61.9                        4.8
# 134       Hungary  2023  135th   48.8                        3.5
# 50   Sierra Leone  2023   51st   81.4                        8.4
# 137       Croatia  2023  138th   48.7                        4.8
#
#      S2: Refugees and IDPs  C3: Group Grievance  \
# 20                     8.2                  5.8
# 36                     8.3                  7.6
# 160                    2.6                  1.9
# 56                     5.8                  4.9
# ...

# %%
import pandas as pd
xl=pd.read_excel(r"C:\Users\LENOVO\Desktop\pandas\FSI-2023-DOWNLOAD.xlsx")
print(pd.options.display.max_rows)
print(pd.options.display.min_rows)
#print(pd.options.display.min_colum)
print(pd.options.display.max_rows==50)
print(pd.options.display.max_columns)
# Out:
# 60
# 10
# False
# 20

# %%
import numpy as np
import pandas as pd
rand=pd.DataFrame(np.random.rand(5,3),columns=['rand-1','rand-2','rand-3'],index=['a','b','c','d','e'])
rand
# Out:
#      rand-1    rand-2    rand-3
# a  0.111674  0.003417  0.767794
# b  0.278761  0.949882  0.654639
# c  0.358757  0.495546  0.142254
# d  0.993119  0.835263  0.284080
# e  0.804122  0.897357  0.912412

# %%
import pandas as pd
xl=pd.read_excel(r"C:\Users\LENOVO\Desktop\pandas\FSI-2023-DOWNLOAD.xlsx")
xl
xl.index
xl.memory_usage()
# Out:
# Index                                132
# Country                             1432
# Year                                1432
# Rank                                1432
# Total                               1432
# S1: Demographic Pressures           1432
# S2: Refugees and IDPs               1432
# C3: Group Grievance                 1432
# E3: Human Flight and Brain Drain    1432
# E2: Economic Inequality             1432
# E1: Economy                         1432
# P1: State Legitimacy                1432
# P2: Public Services                 1432
# P3: Human Rights                    1432
# C1: Security Apparatus              1432
# C2: Factionalized Elites            1432
# X1: External Intervention           1432
# dtype: int64

# %%
import pandas as pd
xl=pd.read_excel(r"C:\Users\LENOVO\Desktop\pandas\FSI-2023-DOWNLOAD.xlsx")
#xl1=pd.DataFrame(xl)
xl.index
xl.shape
xl.ndim
xl.size
xl.memory_usage
xl.empty
#xl1.name()
# Out:
# False

# %%
operators = ['AT&T', 'Verizon', 'T-Mobile US', 'US Cellular']
revenue = [171.76, 128.29, 68.4, 4.04]

#creating a Series from lists
telecom = pd.Series(revenue, index=operators)
telecom
print(telecom[0])
# Out:
# 171.76
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8916\1906859956.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(telecom[0])

# %%
operators = ['AT&T', 'Verizon', 'T-Mobile US', 'US Cellular']
revenue = [171.76, 128.29, 68.4, 4.04]

#creating a Series from lists
telecom = pd.Series(revenue, index=operators)
telecom
telecom['AT&T']
telecom['Verizon']
telecom['T-Mobile US']
# Out:
# 68.4

# %%
#----------------------Attributes----------------------------
#1Index-return all the values-------Series.Index
#2array-return an array of values------Series.array
#3values-return values of series -----Series.values
#name-----return name of series--------Series.name
#4shape--------Series.shape----------return the shape
#5ndim------Series.ndim----------retuns te dimenion of shape
#size-------series.size--------return size of series
#nbytes-series.nbytes-return the memory occupied by values.
#memory-usage()---------Series..memory-usage()-returns memory occupied by both indexes&values
#empty---------series.empty-return the series is empty false-if series is not empty

# %%
s=pd.Series([10,20,30,40,50],index=['a','b','c','d','e'],name="Numbers")
s.index
s.index
s.array
s.values
s.dtype
s.ndim
s.shape
s.array
#s.nbytes
s.memory_usage()
s.memory_usage(index=False)
s.size
s.name
s.empty
s.shape
# Out:
# (5,)

# %%
#applying mathametical operations in pandas------>
#arithmetic operator(+,-,*,/,<,>,==)

# %%
import pandas as pd
s1=pd.Series([10,20,30])
s2=pd.Series([40,50,60])
s1.add(s2)
# Out:
# 0    50
# 1    70
# 2    90
# dtype: int64

# %%
s1.subtract(s2)
# Out:
# 0   -30
# 1   -30
# 2   -30
# dtype: int64

# %%
s1.multiply(s2)
# Out:
# 0     400
# 1    1000
# 2    1800
# dtype: int64

# %%
s1.divide(s2)
# Out:
# 0    0.25
# 1    0.40
# 2    0.50
# dtype: float64

# %%
s1.mod(s2)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s1.pow(s2)
# Out:
# 0   -5047021154770878464
# 1                      0
# 2    1152921504606846976
# dtype: int64

# %%
s1.le(s2)
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
s1.gt(s2)
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
import pandas as pd
a=pd.read_excel(r"C:\Users\LENOVO\Desktop\pandas\FSI-2023-DOWNLOAD.xlsx")
a.describe()
a.head()
# Out:
#                      Country  Year Rank  Total  S1: Demographic Pressures  \
# 0                    Somalia  2023  1st  111.9                       10.0
# 1                      Yemen  2023  2nd  108.9                        9.6
# 2                South Sudan  2023  3rd  108.5                        9.7
# 3  Congo Democratic Republic  2023  4th  107.2                        9.7
# 4                      Syria  2023  5th  107.1                        7.4
#
#    S2: Refugees and IDPs  C3: Group Grievance  \
# 0                    9.0                  8.7
# 1                    9.6                  8.8
# 2                   10.0                  8.6
# 3                    9.8                  9.4
# 4                    9.1                  9.1
#
#    E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  \
# 0                               8.6                      9.1          9.5
# 1                               6.4                      7.9          9.9
# ...

# %%
import pandas as pd
b=pd.read_excel(r"C:\Users\LENOVO\Desktop\pandas\FSI-2023-DOWNLOAD.xlsx")
a=pd.DataFrame(b)
a.head()
a.head(2)
a.tail()
a.tail(5)
a.describe()
#a.columns
a.shape
a.index
#a.columns
#a['Country'].head()
a[['Country','Year','Rank']].head(10)
a[['Country','Year','Rank']].tail(2)
a[1:10:5]
a[['Country','Year','Total']][0:6]
a.loc[1]
a.loc[2:8]
#for index,rows in a.iterrows():
 #   print(index,rows[['Country','Total','Rank']])
# Out:
#                      Country  Year Rank  Total  S1: Demographic Pressures  \
# 2                South Sudan  2023  3rd  108.5                        9.7
# 3  Congo Democratic Republic  2023  4th  107.2                        9.7
# 4                      Syria  2023  5th  107.1                        7.4
# 5                Afghanistan  2023  6th  106.6                        9.2
# 6                      Sudan  2023  7th  106.2                        8.8
# 7   Central African Republic  2023  8th  105.7                        9.3
# 8                       Chad  2023  9th  104.6                        9.5
#
#    S2: Refugees and IDPs  C3: Group Grievance  \
# 2                   10.0                  8.6
# 3                    9.8                  9.4
# 4                    9.1                  9.1
# 5                    8.6                  8.3
# 6                    9.6                  9.3
# 7                    9.5                  8.1
# 8                    9.0                  8.1
# ...

# %%
a.loc[a['Country']=='Chad']
# Out:
#   Country  Year Rank  Total  S1: Demographic Pressures  S2: Refugees and IDPs  \
# 8    Chad  2023  9th  104.6                        9.5                    9.0
#
#    C3: Group Grievance  E3: Human Flight and Brain Drain  \
# 8                  8.1                               7.7
#
#    E2: Economic Inequality  E1: Economy  P1: State Legitimacy  \
# 8                      8.7          8.4                   9.1
#
#    P2: Public Services  P3: Human Rights  C1: Security Apparatus  \
# 8                  9.6               8.4                     8.7
#
#    C2: Factionalized Elites  X1: External Intervention
# 8                       9.5                        7.9

# %%
#Sorting
import pandas as pd
z=pd.read_excel(r"C:\Users\LENOVO\Desktop\pandas\FSI-2023-DOWNLOAD.xlsx")
az=pd.DataFrame(z)
az.sort_values("Country")
az.sort_values('Country',ascending=False).head(10)
#az.sort_values(['Country','Total'],ascending=[0,1]).head(50)
# Out:
#                   Country  Year   Rank  Total  S1: Demographic Pressures  \
# 15               Zimbabwe  2023   16th   96.9                        8.7
# 47                 Zambia  2023   48th   81.8                        9.4
# 1                   Yemen  2023    2nd  108.9                        9.6
# 117               Vietnam  2023  118th   58.3                        4.4
# 28              Venezuela  2023   29th   90.5                        6.5
# 94             Uzbekistan  2023   95th   66.8                        4.3
# 156               Uruguay  2023  157th   34.4                        3.4
# 140         United States  2023  141st   45.3                        5.2
# 147        United Kingdom  2023  148th   41.9                        3.4
# 155  United Arab Emirates  2023  156th   37.0                        3.6
#
#      S2: Refugees and IDPs  C3: Group Grievance  \
# 15                     7.6                  5.9
# 47                     4.9                  5.9
# ...

# %%
#manipulating data,drop and addd
import pandas as pd
w=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\dateTime.csv")
qw=pd.DataFrame(w)
#print(qw)
qw['Total_calories']=0
qw
qw['Total_calories']=qw['Maxpulse']+qw['Calories']
qw
qw.describe()
qw['Total_pulse']=0
qw
qw['Total_pulse']=qw['Pulse']+qw['Maxpulse']
qw
qw.drop(columns='Date')
# Out:
#      Duration  Pulse  Maxpulse  Calories  Total_calories  Total_pulse
# 0          60    110       130     409.1           539.1          240
# 1          60    117       145     479.0           624.0          262
# 2          60    103       135     340.0           475.0          238
# 3          45    109       175     282.4           457.4          284
# 4          45    117       148     406.0           554.0          265
# ..        ...    ...       ...       ...             ...          ...
# 164        60    105       140     290.8           430.8          245
# 165        60    110       145     300.0           445.0          255
# 166        60    115       145     310.2           455.2          260
# 167        75    120       150     320.4           470.4          270
# 168        75    125       150     330.4           480.4          275
#
# [169 rows x 6 columns]

# %%
qw[['Pulse','Maxpulse','Total_pulse']]
# Out:
#      Pulse  Maxpulse  Total_pulse
# 0      110       130          240
# 1      117       145          262
# 2      103       135          238
# 3      109       175          284
# 4      117       148          265
# ..     ...       ...          ...
# 164    105       140          245
# 165    110       145          255
# 166    115       145          260
# 167    120       150          270
# 168    125       150          275
#
# [169 rows x 3 columns]

# %%
qw[['Duration','Calories']]
# Out:
#      Duration  Calories
# 0          60     409.1
# 1          60     479.0
# 2          60     340.0
# 3          45     282.4
# 4          45     406.0
# ..        ...       ...
# 164        60     290.8
# 165        60     300.0
# 166        60     310.2
# 167        75     320.4
# 168        75     330.4
#
# [169 rows x 2 columns]

# %%
import pandas as pd
exp=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\dateTime.csv")
exp1=pd.DataFrame(exp)
exp1
exp1['Totalcalories']=0
exp1
exp1['Totalcalories']=exp1['Maxpulse']+exp1['Calories']
exp1
exp1.drop(columns='Date')
exp1.to_csv("C:\\Users\LENOVO\\Desktop\\pandas\\dateTime_updates.csv")

# %%
import pandas as pd
exc=pd.read_excel(r"C:\Users\LENOVO\Desktop\pandas\FSI-2023-DOWNLOAD.xlsx")
opt=pd.DataFrame(exc)
opt
opt.drop(columns= ["X1: External Intervention","C2: Factionalized Elites","C1: Security Apparatus"])
opt.to_excel("C:\\Users\\LENOVO\\Desktop\\pandas\\FSI-update.xlsx")

# %%
import pandas as pd
xc=pd.read_excel(r"C:\\Users\\LENOVO\\Desktop\\pandas\\FSI-update.xlsx")
xcz=pd.DataFrame(xc)
xcz
#xcz.Total.mean
#xcz.Country.mean
# Out:
#      Unnamed: 0                    Country  Year   Rank  Total  \
# 0             0                    Somalia  2023    1st  111.9
# 1             1                      Yemen  2023    2nd  108.9
# 2             2                South Sudan  2023    3rd  108.5
# 3             3  Congo Democratic Republic  2023    4th  107.2
# 4             4                      Syria  2023    5th  107.1
# ..          ...                        ...   ...    ...    ...
# 174         174                Switzerland  2023  175th   17.8
# 175         175                New Zealand  2023  176th   16.7
# 176         176                    Finland  2023  177th   16.0
# 177         177                    Iceland  2023  178th   15.7
# 178         178                     Norway  2023  179th   14.5
#
#      S1: Demographic Pressures  S2: Refugees and IDPs  C3: Group Grievance  \
# 0                         10.0                    9.0                  8.7
# ...

# %%
#iloc&loc
import pandas as pd
value=pd.read_excel(r"C:\\Users\\LENOVO\\Desktop\\pandas\\FSI-update.xlsx")
value1=pd.DataFrame(value)
value1.loc[3,"Country"]
value1.loc[0:4,["Country","Year"]]
value1.loc[0:4,"Country":"Total"]
#value1.loc[0:4,["Country","Year"]]
#value1.loc[0:4,"Country":"S1: Demographic Pressures"]
#value1.loc[0:9,["Country","C3: Group Grievance"]]
#value1.loc[0:9,"Country":"C3: Group Grievance"]
# Out:
#                      Country  Year Rank  Total
# 0                    Somalia  2023  1st  111.9
# 1                      Yemen  2023  2nd  108.9
# 2                South Sudan  2023  3rd  108.5
# 3  Congo Democratic Republic  2023  4th  107.2
# 4                      Syria  2023  5th  107.1

# %%
#iloc
#value1.iloc[0:4,1:8]
#value1.loc[0:4,"Country":"Total"]
#value1.loc[0:4,["Country","Total"]]
#value1.iloc[0:8,0:2]
#value1.head()

# %%
value1.iloc[:,[1,3]]
value1.iloc[:,[3,7]]
# Out:
#       Rank  C3: Group Grievance
# 0      1st                  8.7
# 1      2nd                  8.8
# 2      3rd                  8.6
# 3      4th                  9.4
# 4      5th                  9.1
# ..     ...                  ...
# 174  175th                  2.1
# 175  176th                  2.0
# 176  177th                  0.3
# 177  178th                  0.5
# 178  179th                  3.1
#
# [179 rows x 2 columns]

# %%
#missing data
miss=pd.read_excel(r"C:\Users\LENOVO\Desktop\pandas\Book1.xlsx")
data=pd.DataFrame(miss)
#data
#print(data.dropna())
#print(data.dropna(inplace=True))
data
# Out:
#                                            Unnamed: 0
# 0                                                 NaN
# 1   | Student ID | Tamil | English | Maths | Scien...
# 2   |------------|-------|---------|-------|------...
# 3   | Abishek      | 85    | 78      | 92    | 88 ...
# 4   | sogail        | 90    | 81      | 85    | 92...
# 5   | preetha          | 76    | 85      | 88    |...
# 6   | crysta         | 82    | 79      | 90    | 8...
# 7   | kia         | 89    | 80      | 84    | 91  ...
# 8                                                 NaN
# 9   |        | 88    | 82      | 87    | 89      |...
# 10  | sam        | 79    | 86      | 91    | 84   ...
# 11  | dora     | 85    | 83      | 82    | 88     ...
# 12  | chutki        | 92    | 79      | 90    | 87...
# 13  | bindhu       | 80    | 84      | 77    | 82 ...
# 14                                                NaN
# 15  | wonderie      | 73    | 81      | 88    | 85...
# ...

# %%
import pandas as pd
csv=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\info.csv")
cs=pd.DataFrame(csv)
cs.dropna()
cs[["Duration","Pulse"]].dropna()
cs.loc[:,["Duration"]].dropna()
cs.fillna("Data MIssing")
cs["Pulse"].fillna(112,inplace=True)
cs.loc[:,["Maxpulse","Calories"]].fillna(113)
cs["Maxpulse"].fillna(120,inplace=True)
cs
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  112.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0     148.0     406.0
# 5       60.0  '2020/12/04'  102.0     127.0     300.0
# 6       60.0  '2020/12/04'  110.0     136.0     374.0
# 7      450.0  '2020/12/04'  104.0     134.0     253.3
# 8       30.0  '2020/12/04'  109.0     133.0     195.1
# 9       60.0  '2020/12/04'   98.0     124.0     269.0
# 10      60.0  '2020/12/04'  103.0     147.0     329.3
# 11      60.0  '2020/12/04'  100.0     120.0     250.7
# 12       NaN  '2020/12/04'  100.0     120.0       NaN
# 13      60.0  '2020/12/04'  106.0     128.0     345.3
# 14      60.0  '2020/12/04'  104.0     132.0     379.3
# 15      60.0  '2020/12/04'   98.0     123.0     275.0
# ...

# %%
#Remove Duplicates in Data Frame
import pandas as pd
cx=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\info.csv")
csx=pd.DataFrame(cx)
csx["Calories"].fillna(300,inplace=True)
csx["Maxpulse"].fillna(118,inplace=True)
csx["Duration"].fillna(60.0,inplace=True)
csx["Pulse"].fillna(117.0,inplace=True)
csx
csx.duplicated('Calories').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
csx.drop_duplicates()
csx.drop_duplicates(inplace=True)
csx
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  117.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0     148.0     406.0
# 5       60.0  '2020/12/04'  102.0     127.0     300.0
# 6       60.0  '2020/12/04'  110.0     136.0     374.0
# 7      450.0  '2020/12/04'  104.0     134.0     253.3
# 8       30.0  '2020/12/04'  109.0     133.0     195.1
# 9       60.0  '2020/12/04'   98.0     124.0     269.0
# 10      60.0  '2020/12/04'  103.0     147.0     329.3
# 11      60.0  '2020/12/04'  100.0     120.0     250.7
# 12      60.0  '2020/12/04'  100.0     120.0     300.0
# 13      60.0  '2020/12/04'  106.0     128.0     345.3
# 14      60.0  '2020/12/04'  104.0     132.0     379.3
# 15      60.0  '2020/12/04'   98.0     123.0     275.0
# ...

# %%
#Data Filtering-
wqw=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\dateTime_updates.csv")
i=pd.DataFrame(wqw)
i
i.loc[i['Pulse']<110]
i.loc[i['Duration']>30]
i.loc[(i["Pulse"]<117)&(i["Maxpulse"]<120)]
#i.loc[(i["Pulse"]<117)|(i["Maxpulse"]<120)].head()
# Out:
#      Unnamed: 0  Duration  Pulse  Maxpulse  Calories               Date  \
# 17           17        45     90       112       NaN    '2020/12/17'
# 21           21        45    100       119     282.0     '2020/12/21'
# 26           26        60     92       118     241.0      '2020/12/19'
# 30           30        60     92       115     243.0    '2020/12/30'
# 31           31        45     90       112     180.1   '2020/12/31'
# 33           33        60     93       113     223.0   '2020/12/02'
# 40           40        45     90       112     180.1    '2020/12/09'
# 45           45        60     99       119     273.0     '2020/12/13'
# 89           89        20     83       107      50.3     '2020/12/25'
# 92           92        30     90       107     105.3     '2020/12/28'
# 93           93        15     80       100      50.5     '2020/12/29'
# 100         100        20     95       112      77.7    '2020/12/05'
# ...

# %%
#conditinal Chnges----
import pandas as pd
p=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\dateTime_updates.csv")
kd=pd.DataFrame(p)
kd.sample(10)
kd['Total']=kd["Duration"]+kd["Pulse"]+kd["Maxpulse"]+kd["Calories"]+kd["Totalcalories"]
kd.head()
kd['Percentage']=(kd["Total"]/500)
kd['exp']=(kd["Total"]*2)
kd["Status"]="None"
kd
#kd.loc[kd['Calories']>400,['Status']]="Bad"
#kd.loc[kd['Calories']<400,['Status']]="Good"
#kd['Calories'].unique()
#kd['Calories'].value_counts()
kd.groupby(['Calories'])['Pulse'].mean()
kd.columns
kd.rename(columns={'Duration':'Duara_tion'},inplace=True)
kd.drop(columns='Unnamed: 0',inplace=True)

kd.head()
kd.columns
# Out:
# Index(['Duara_tion', 'Pulse', 'Maxpulse', 'Calories', 'Date', 'Totalcalories',
#        'Total', 'Percentage', 'exp', 'Status'],
#       dtype='object')

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
import pandas as pd
qw=pd.read_csv(r"C:\Users\LENOVO\Desktop\pandas\info.csv")
aq=pd.DataFrame(qw)
for i in aq. index:
    if aq.loc[i,"Calories"]>300:
        aq.drop(i,inplace=True)
aq
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 5       60.0  '2020/12/04'  102.0     127.0     300.0
# 7      450.0  '2020/12/04'  104.0     134.0     253.3
# 8       30.0  '2020/12/04'  109.0     133.0     195.1
# 9       60.0  '2020/12/04'   98.0     124.0     269.0
# 11      60.0  '2020/12/04'  100.0     120.0     250.7
# 12       NaN  '2020/12/04'  100.0     120.0       NaN
# 15      60.0  '2020/12/04'   98.0     123.0     275.0
# 16      60.0  '2020/12/04'   98.0     120.0     215.2
# 17      60.0  '2020/12/05'  100.0     120.0     300.0
# 18      45.0  '2020/12/05'   90.0     112.0       NaN
# 20      45.0  '2020/12/05'   97.0     125.0     243.0
# 22      45.0  '2020/12/05'  100.0     119.0     282.0
# 23      60.0  '2020/12/05'  130.0     101.0     300.0
# 24      45.0  '2020/12/05'  105.0     132.0     246.0
# 26      60.0  '2020/12/05'  100.0     120.0     250.0
# ...

# %%
#pandas as series convert to list
import pandas as pd
s=pd.Series([2,4,5,6,7,8])
print(s)
print(type(s))
print(s.tolist())
print(type(s.tolist()))
# Out:
# 0    2
# 1    4
# 2    5
# 3    6
# 4    7
# 5    8
# dtype: int64
# <class 'pandas.core.series.Series'>
# [2, 4, 5, 6, 7, 8]
# <class 'list'>

# %%
import pandas as pd
s=pd.Series([2,4,5,6,7,8])
